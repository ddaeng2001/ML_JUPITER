# %%
import pandas as pd

df = pd.DataFrame({
    "메뉴": ['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격": ["4500", "NA", "5500", "-", "4000", "5900", "-"],
    "칼로리": [10, 110, 250, 110, 20, 210, 0],
})
df
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼    NA  110
# 2   카페모카  5500  250
# 3   카푸치노     -  110
# 4  에스프레소  4000   20
# 5    밀크티  5900  210
# 6     녹차     -    0

# %%
# df.to_csv("cafe_index.csv") #내보내기
temp = pd.read_csv("cafe_index.csv") #내보내기 파일 가져오기
temp.head()
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20

# %%
df.to_csv("cafe2.csv", index=False)
df2 = pd.read_csv("cafe2.csv")
df2.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.to_csv("cafe_semicolon.csv", sep=";", index=False)
df3 = pd.read_csv("cafe_semicolon.csv", sep=";")
df3.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.to_csv("cafe_menu_price.csv", columns=["메뉴", "가격"], index=False)
pd.read_csv("cafe_menu_price.csv").head()
# Out:
#       메뉴    가격
# 0  아메리카노  4500
# 1   카페라떼  5000
# 2   카페모카  5500
# 3   카푸치노  5000
# 4  에스프레소  4000

# %%
df.to_csv("cafe_utf8.csv", columns=["메뉴", "가격"], index=False, encoding="utf-8-sig")
df4=pd.read_csv("cafe_menu_price.csv").head()
df4
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_csv("cafe_utf8.csv", columns=["메뉴", "가격"], index=False, encoding="utf-8-sig")
#       2 df4=pd.read_csv("cafe_menu_price.csv").head()
#       3 df4
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/formats/format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/formats/csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'cafe_utf8.csv'

# %%
df.to_excel("cafe.xlsx", index=False, sheet_name="메뉴판")
                                        #엑셀 네부의 이름 지정

# %%
df_xls = pd.read_excel("cafe.xlsx", sheet_name="메뉴판")
df_xls.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.to_json("cafe.json", orient="records", force_ascii=False)
                                          #force_ascii:유니코드/아스키코드표 기준으로 값이 추출됨  
                        #record = [{},{},{}] : 배열안의 object
                        #JS에서 함수쓰기 용이하기 때문에 record가 기본임!
                        #values = [[],[],[]]
                        #table도 있음!

# %%
df_json = pd.read_json("cafe.json")
df_json.head() #head() : 상단의 몇 개 정도만 추출해서 보여줌
                    #괄호 안에 숫자만큼의 표 개수가 나옴
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.to_pickle("cafe.pkl")

# %%
df_pkl = pd.read_pickle("cafe.pkl")
df_pkl.head()
# Out:
#       메뉴    가격  칼로리
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
df.to_csv("cafe_noheader.csv", index=False, header=False)

# %%
df_noheader = pd.read_csv("cafe_noheader.csv", header=None)
df_noheader.head()
# Out:
#        0     1    2
# 0  아메리카노  4500   10
# 1   카페라떼  5000  110
# 2   카페모카  5500  250
# 3   카푸치노  5000  110
# 4  에스프레소  4000   20

# %%
# 인덱스 컬럼을 메뉴로!
df.to_csv("cafe_index_menu.csv", index=False)
df_indexed = pd.read_csv("cafe_index_menu.csv", index_col="메뉴")
df_indexed.head()
# Out:
#          가격  칼로리
# 메뉴
# 아메리카노  4500   10
# 카페라떼   5000  110
# 카페모카   5500  250
# 카푸치노   5000  110
# 에스프레소  4000   20

# %%
# 문제 start #

# %%
# df.to_csv("cafe_basic.csv")
# df_basic = pd.read_csv("cafe_basic.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      object
#  2   칼로리     7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      object
#  2   칼로리     7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes

# %%
#파일을 가져오면서 자료형 변경
# df_types = pd.read_csv("cafe.csv", dtype={"가격": "int64"})

df["가격"] = df["가격"].astype("int64")
                #각각의 가격 type을 integer로 변경!
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   메뉴      7 non-null      object
#  1   가격      7 non-null      int64
#  2   칼로리     7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df.to_csv("cafe_no_index.csv", index="False")
df_no_index= pd.read_csv("cafe_no_index.csv")

# %%
df.to_csv("cafe_menu_price.csv",columns=['메뉴', '가격'], index="False")
a = pd.read_csv("cafe_menu_price.csv")
a
# Out:
#    Unnamed: 0     메뉴    가격
# 0           0  아메리카노  4500
# 1           1   카페라떼  5000
# 2           2   카페모카  5500
# 3           3   카푸치노  5000
# 4           4  에스프레소  4000
# 5           5    밀크티  5900
# 6           6     녹차  5300

# %%
df.to_csv("cafe_sc.csv", sep=";", index="False")
b = pd.read_csv("cafe_sc.csv", sep=";")
b
# Out:
#    Unnamed: 0     메뉴    가격  칼로리
# 0           0  아메리카노  4500   10
# 1           1   카페라떼  5000  110
# 2           2   카페모카  5500  250
# 3           3   카푸치노  5000  110
# 4           4  에스프레소  4000   20
# 5           5    밀크티  5900  210
# 6           6     녹차  5300    0

# %%
# 결측치 기호 지정
# cafe.csv를 읽을 때 문자열 'NA'와 '-'를 결측치로 인식할 것
# 형변환이 아닌 파일로 빼는 작업
df.to_csv("cafe_test.csv")
cafe_test_df = pd.read_csv("cafe_test.csv", na_values=["NA","-"])
cafe_test_df
# Out:
#    Unnamed: 0     메뉴      가격  칼로리
# 0           0  아메리카노  4500.0   10
# 1           1   카페라떼     NaN  110
# 2           2   카페모카  5500.0  250
# 3           3   카푸치노     NaN  110
# 4           4  에스프레소  4000.0   20
# 5           5    밀크티  5900.0  210
# 6           6     녹차     NaN    0

# %%
# Excel 다중 시트 저장
with pd.ExcelWriter("cafe_multi.xlsx") as writer:
    #with as : 자원제거작업포함
    print(writer)
        #엑셀로 만들겠다!, 인덱스를 제외한 모든 것을 삽입
    df.to_excel(writer, sheet_name="전체", index=False)
    
    low_cal = df[df["칼로리"] <= 100] # 컬럼명을 생략함으로서 전체 컬럼이 나오도록
    low_cal.to_excel(writer, sheet_name="저칼로리", index=False)
# Out:
# <pandas.io.excel._openpyxl.OpenpyxlWriter object at 0x78cc642710d0>
